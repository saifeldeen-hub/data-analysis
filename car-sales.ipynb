# %% [markdown]
# # importing libs

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# # reading data

# %%
df=pd.read_csv('Car_Sales.csv',encoding='ISO-8859-1')

# %% [markdown]
# # viewing data

# %%
df
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 472320  2011     BMW             5 Series         528i      Sedan
# 472321  2012     Ram                 2500  Power Wagon   Crew Cab
# 472322  2012     BMW                   X5    xDrive35d        SUV
# 472323  2015  Nissan               Altima        2.5 S      sedan
# 472324  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission                vin state  condition  odometer  color  \
# 0         automatic  5xyktca69fg566472    ca          5     16639  white
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 472325 entries, 0 to 472324
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   year          472325 non-null  int64
#  1   make          472325 non-null  object
#  2   model         472325 non-null  object
#  3   trim          472325 non-null  object
#  4   body          472325 non-null  object
#  5   transmission  472325 non-null  object
#  6   vin           472325 non-null  object
#  7   state         472325 non-null  object
#  8   condition     472325 non-null  int64
#  9   odometer      472325 non-null  int64
#  10  color         472325 non-null  object
#  11  interior      472325 non-null  object
#  12  seller        472325 non-null  object
#  13  mmr           472325 non-null  int64
#  14  sellingprice  472325 non-null  int64
#  15  saledate      472325 non-null  object
# dtypes: int64(5), object(11)
# memory usage: 57.7+ MB

# %%
df.describe()
# Out:
#                 year      condition       odometer            mmr  \
# count  472325.000000  472325.000000  472325.000000  472325.000000
# mean     2010.210980      30.774177   66701.732040   13837.058964
# std         3.822151      13.286866   51939.586894    9532.229273
# min      1990.000000       1.000000       1.000000      25.000000
# 25%      2008.000000      24.000000   28137.000000    7425.000000
# 50%      2012.000000      35.000000   51085.000000   12300.000000
# 75%      2013.000000      41.000000   96590.000000   18300.000000
# max      2015.000000      49.000000  999999.000000  182000.000000
#
#         sellingprice
# count  472325.000000
# mean    13690.512058
# std      9613.033738
# min         1.000000
# 25%      7200.000000
# 50%     12200.000000
# 75%     18200.000000
# max    230000.000000

# %%
df.describe(include='O')
# Out:
#           make   model    trim    body transmission                vin  \
# count   472325  472325  472325  472325       472325             472325
# unique      53     768    1494      85            2             465768
# top       Ford  Altima    Base   Sedan    automatic  5uxfe43579l274932
# freq     81013   16346   48779  174647       455963                  4
#
#          state   color interior                         seller  \
# count   472325  472325   472325                         472325
# unique      34      20       17                          11923
# top         fl   black    black  ford motor credit company llc
# freq     75243   93244   209865                          17756
#
#                                        saledate
# count                                    472325
# unique                                     3609
# top     Tue Feb 10 2015 01:30:00 GMT-0800 (PST)
# freq                                       5004

# %%
plt.figure(figsize=(20,10))
plt.title('Scatter plot of odometer vs sellingprice')
plt.xlabel('odometer')
plt.ylabel('sellingprice')
sns.scatterplot(x='odometer',y='sellingprice',data=df)
plt.show()

# %%
df
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 472320  2011     BMW             5 Series         528i      Sedan
# 472321  2012     Ram                 2500  Power Wagon   Crew Cab
# 472322  2012     BMW                   X5    xDrive35d        SUV
# 472323  2015  Nissan               Altima        2.5 S      sedan
# 472324  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission                vin state  condition  odometer  color  \
# 0         automatic  5xyktca69fg566472    ca          5     16639  white
# ...

# %%
plt.figure(figsize=(20,10))
plt.title('condition vs sellingprice')
plt.xlabel('condition')
plt.ylabel('sellingprice')
sns.scatterplot(x='condition',y='sellingprice',data=df)
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.title('body type vs sellingprice')
plt.xlabel('body type')
plt.ylabel('sellingprice')
sns.barplot(x='body',y='sellingprice',data=df)
plt.show()

# %%
df['body'].value_counts()
# Out:
# body
# Sedan              174647
# SUV                100347
# sedan               36651
# suv                 20621
# Hatchback           19351
#                     ...
# g37 convertible         3
# CTS-V Wagon             1
# Ram Van                 1
# cab plus 4              1
# cts wagon               1
# Name: count, Length: 85, dtype: int64

# %%
body_count=df.groupby('body')['body'].value_counts().reset_index()
body_count
# Out:
#                   body  count
# 0           Access Cab    210
# 1   Beetle Convertible     46
# 2            CTS Coupe    102
# 3            CTS Wagon     10
# 4          CTS-V Coupe     20
# ..                 ...    ...
# 80         transit van      7
# 81     tsx sport wagon      6
# 82                 van    444
# 83               wagon   2200
# 84             xtracab      4
#
# [85 rows x 2 columns]

# %%
x=len(body_count)
x
# Out:
# 85

# %%
top=body_count.head(30)

# %%
for i in range (0,len(top),10):
    plt.figure(figsize=(20,10))
    plt.title('body count in dataframe')
    plt.xlabel('body')
    plt.ylabel('count')
    x=sns.barplot(x=top.iloc[i:i+10]['body'],y=top.iloc[i:i+10]['count'],data=top)
    for container in x.containers:
        x.bar_label(container)
    plt.show()

# %%
df
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 472320  2011     BMW             5 Series         528i      Sedan
# 472321  2012     Ram                 2500  Power Wagon   Crew Cab
# 472322  2012     BMW                   X5    xDrive35d        SUV
# 472323  2015  Nissan               Altima        2.5 S      sedan
# 472324  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission                vin state  condition  odometer  color  \
# 0         automatic  5xyktca69fg566472    ca          5     16639  white
# ...

# %%
plt.figure(figsize=(10,10))
plt.title('sellingprice histogram')
plt.xlabel('sellingprice')
plt.ylabel('count')
sns.boxplot(df['sellingprice'])
plt.show()

# %%
print(df['sellingprice'].max())
print(df['sellingprice'].min())
# Out:
# 230000
# 1

# %%
df['selling-df']=df['sellingprice']-df['mmr']

# %%
plt.figure(figsize=(10,10))
plt.title('sellingprice histogram')
plt.xlabel('sellingprice')
plt.ylabel('count')
sns.boxplot(df['selling-df'])
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.title('sellingprice histogram')
plt.xlabel('sellingprice')
plt.ylabel('count')
sns.histplot(df['sellingprice'])
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.title('interior vs sellingprice')
plt.xlabel('interior')
plt.ylabel('sellingprice')
sns.barplot(x='interior',y='sellingprice',data=df)
plt.show()
# Out:
# C:\Users\mmsai\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 151 (\x97) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
interior_sellingprice=df.groupby('interior')['sellingprice'].sum().reset_index()

# %%
interior_sellingprice
# Out:
#      interior  sellingprice
# 0       beige     674943056
# 1       black    3268683013
# 2        blue       7939175
# 3       brown     143221976
# 4    burgundy       2917650
# 5        gold       3414600
# 6        gray    1700510034
# 7       green       2079175
# 8   off-white      10413125
# 9      orange       2525950
# 10     purple       3893026
# 11        red      27321575
# 12     silver      10980850
# 13        tan     475366228
# 14      white       4094027
# 15     yellow        346300
# 16               127721348

# %%
for i in range (0,len(interior_sellingprice),4):
    plt.figure(figsize=(20,10))
    plt.title('interior vs sellingprice')
    plt.xlabel('interior')
    plt.ylabel('sellingprice')
    x=sns.barplot(x=interior_sellingprice.iloc[i:i+4]['interior'],y=interior_sellingprice.iloc[i:i+4]['sellingprice'],data=interior_sellingprice)
    for container in x.containers:
        x.bar_label(container)
    plt.show()
# Out:
# C:\Users\mmsai\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 151 (\x97) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 472320  2011     BMW             5 Series         528i      Sedan
# 472321  2012     Ram                 2500  Power Wagon   Crew Cab
# 472322  2012     BMW                   X5    xDrive35d        SUV
# 472323  2015  Nissan               Altima        2.5 S      sedan
# 472324  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission                vin state  condition  odometer  color  \
# 0         automatic  5xyktca69fg566472    ca          5     16639  white
# ...

# %%
df['color'].value_counts()
# Out:
# color
# black        93244
# white        89233
# silver       71251
# gray         70640
# blue         43060
# red          37336
#             22068
# gold          9563
# green         9234
# burgundy      7605
# beige         7444
# brown         5621
# orange        1763
# purple        1270
# off-white     1244
# yellow        1079
# charcoal       429
# turquoise      190
# pink            39
# lime            12
# Name: count, dtype: int64

# %%
color_sellingprice=df.groupby('color')['sellingprice'].sum().reset_index().sort_values(by='sellingprice',ascending=False)
color_sellingprice
# Out:
#         color  sellingprice
# 1       black    1442866834
# 17      white    1326318247
# 7        gray     985882549
# 15     silver     844105904
# 2        blue     497335254
# 14        red     481549366
# 19               393348864
# 4    burgundy      92155066
# 3       brown      87304137
# 6        gold      82450307
# 8       green      81264961
# 0       beige      70893993
# 11     orange      23098988
# 10  off-white      19126002
# 13     purple      15593103
# 18     yellow      13791580
# 5    charcoal       6973851
# 16  turquoise       1675102
# 12       pink        484150
# 9        lime        152850

# %%
for i in range (0,len(color_sellingprice),4):
    plt.figure(figsize=(20,10))
    plt.title('color vs sellingprice')
    plt.xlabel('color')
    plt.ylabel('sellingprice')
    x=sns.barplot(x=color_sellingprice.iloc[i:i+4]['color'],y=color_sellingprice.iloc[i:i+4]['sellingprice'],data=color_sellingprice)
    for container in x.containers:
        x.bar_label(container)
    plt.show()
# Out:
# C:\Users\mmsai\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 151 (\x97) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 472320  2011     BMW             5 Series         528i      Sedan
# 472321  2012     Ram                 2500  Power Wagon   Crew Cab
# 472322  2012     BMW                   X5    xDrive35d        SUV
# 472323  2015  Nissan               Altima        2.5 S      sedan
# 472324  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission                vin state  condition  odometer  color  \
# 0         automatic  5xyktca69fg566472    ca          5     16639  white
# ...

# %%
df['transmission'].value_counts()
# Out:
# transmission
# automatic    455963
# manual        16362
# Name: count, dtype: int64

# %%
transmission_sellingprice=df.groupby('transmission')['sellingprice'].sum().reset_index().sort_values(by='sellingprice',ascending=False)

transmission_sellingprice
# Out:
#   transmission  sellingprice
# 0    automatic    6280666968
# 1       manual     185704140

# %%
plt.figure(figsize=(5,5))
plt.title('transmission vs sellingprice')
plt.xlabel('transmission')
plt.ylabel('sellingprice')
x=sns.barplot(x=transmission_sellingprice['transmission'],y=transmission_sellingprice['sellingprice'])
for container in x.containers:
        x.bar_label(container)
plt.show()

# %%
df
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 472320  2011     BMW             5 Series         528i      Sedan
# 472321  2012     Ram                 2500  Power Wagon   Crew Cab
# 472322  2012     BMW                   X5    xDrive35d        SUV
# 472323  2015  Nissan               Altima        2.5 S      sedan
# 472324  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission                vin state  condition  odometer  color  \
# 0         automatic  5xyktca69fg566472    ca          5     16639  white
# ...

# %%
make_selling=df.groupby('make')['sellingprice'].sum().reset_index().sort_values(by='sellingprice',ascending=False)

# %%
for i in range (0,len(make_selling),4):
    plt.figure(figsize=(20,10))
    plt.title('make vs sellingprice')
    plt.xlabel('make')
    plt.ylabel('sellingprice')
    x=sns.barplot(x=make_selling.iloc[i:i+4]['make'],y=make_selling.iloc[i:i+4]['sellingprice'],data=make_selling)
    for container in x.containers:
        x.bar_label(container)
    plt.show()

# %%
df['state'].unique()
# Out:
# array(['ca', 'tx', 'mn', 'az', 'wi', 'tn', 'md', 'pa', 'fl', 'ne', 'oh',
#        'mi', 'nj', 'va', 'sc', 'in', 'il', 'co', 'ut', 'mo', 'ga', 'nv',
#        'ma', 'pr', 'nc', 'ny', 'or', 'la', 'wa', 'hi', 'ok', 'ms', 'nm',
#        'al'], dtype=object)

# %%
state_sellingprice=df.groupby('state')['sellingprice'].sum().reset_index().sort_values(by='sellingprice',ascending=False)

state_sellingprice

for i in range (0,len(state_sellingprice),4):
    plt.figure(figsize=(20,10))
    plt.title('state vs sellingprice')
    plt.xlabel('state')
    plt.ylabel('sellingprice')
    x=sns.barplot(x=state_sellingprice.iloc[i:i+4]['state'],y=state_sellingprice.iloc[i:i+4]['sellingprice'],data=state_sellingprice)
    for container in x.containers:
        x.bar_label(container)
    plt.show()

# %%
df
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 472320  2011     BMW             5 Series         528i      Sedan
# 472321  2012     Ram                 2500  Power Wagon   Crew Cab
# 472322  2012     BMW                   X5    xDrive35d        SUV
# 472323  2015  Nissan               Altima        2.5 S      sedan
# 472324  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission                vin state  condition  odometer  color  \
# 0         automatic  5xyktca69fg566472    ca          5     16639  white
# ...
